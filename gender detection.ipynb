# %%
#GENDER DETECTION

# %%
#create dataframe
import pandas as pd
df=pd.read_csv('/content/Gender_Detection.csv',header=0,encoding='unicode_escape')
df
# Out:
#            Name Gender
# 0         James      M
# 1          John      M
# 2        Robert      M
# 3       Michael      M
# 4       William      M
# ...         ...    ...
# 147264   Zylenn      M
# 147265   Zymeon      M
# 147266   Zyndel      M
# 147267   Zyshan      M
# 147268    Zyton      M
#
# [147269 rows x 2 columns]

# %%
df.shape       #147269 rows 2 cols
# Out:
# (147269, 2)

# %%
df.size
# Out:
# 294538

# %%
df.dtypes
# Out:
# Name      object
# Gender    object
# dtype: object

# %%
#checking for null or missing values
df.isnull().isnull().sum()
# Out:
# Name      0
# Gender    0
# dtype: int64

# %%
#no of male names
df[df.Gender=='M'].size
# Out:
# 115040

# %%
#no of female names
df[df.Gender=='F'].size
# Out:
# 179498

# %%
df['Gender'].value_counts()
# Out:
# F    89749
# M    57520
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Replacing All F and M with 0 and 1 respectively
df.Gender.replace({'F':0,'M':1},inplace=True)

# %%
df.Gender.unique()
# Out:
# array([1, 0])

# %%
Xfeatures =df['Name']

# %%
#Feature Extraction
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
X=cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names_out()
# Out:
# array(['1957975', 'aaban', 'aabha', ..., 'zyyon', 'zzyzx', 'zzziekal'],
#       dtype=object)

# %%
#div data into ip and op

# %%
X
# Out:
# <147269x126927 sparse matrix of type '<class 'numpy.int64'>'
# 	with 154777 stored elements in Compressed Sparse Row format>

# %%
y=df.Gender

# %%
#training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#applying classifier
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()

# %%
#fit the model
clf.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
#accuracy test
clf.score(X_test,y_test)*100
# Out:
# 56.815983867980826

# %%
#accuracy train
clf.score(X_train,y_train)*100
# Out:
# 93.39110165197123

# %%
#individual predictions

# %%
from sklearn.feature_extraction import DictVectorizer
n1=['Natasha']
vect1=cv.transform(n1).toarray()
clf.predict(vect1)
# Out:
# array([0])

# %%
from sklearn.feature_extraction import DictVectorizer
n2=['James']
vect2=cv.transform(n2).toarray()
clf.predict(vect2)
# Out:
# array([1])
